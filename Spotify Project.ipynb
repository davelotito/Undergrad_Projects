# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('top50.csv',encoding = "ISO-8859-1")

# %%
df.head(51)
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
df.sort_values(by='Artist.Name',ascending=True)
df.drop(columns=['Loudness..dB..'],inplace=True)

# %%
df.head(51)
df.sort_values(by=['Track.Name','Artist.Name','Genre'],ascending=True,inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.plot(kind='scatter',x='Popularity',y='Length.',color='red')
plt.show()

# %%
df.head(51)
# Out:
#     Unnamed: 0                                         Track.Name  \
# 32          33                                  0.958333333333333
# 31          32                                            7 rings
# 37          38                     Antisocial (with Travis Scott)
# 3            4                    Beautiful People (feat. Khalid)
# 48          49                                      Call You Mine
# 10          11                                           Callaita
# 1            2                                              China
# 44          45                                         Con Altura
# 28          29                                          Con Calma
# 49          50      Cross Me (feat. Chance the Rapper & PnB Rock)
# 26          27                                       Dance Monkey
# 4            5                        Goodbyes (Feat. Young Thug)
# 47          48                                            Happier
# ...

# %%
df.loc[(df['Beats.Per.Minute'] >= 75) & (df['Energy'] == 71 ), ['Beats.Per.Minute', 'Genre']]
# Out:
#     Beats.Per.Minute      Genre
# 32                96  reggaeton
# 11                96  dance pop
